# %%
import pandas as pd
import json
import os

# %%
import torch
print(torch.backends.mps.is_available()) # MPS 장치가 사용 가능한지 확인합니다. True여야 합니다.
# Out:
# True

# %%
directory_path =os.getcwd()

# %%
files = os.listdir(directory_path)

# %%
files
# Out:
# ['dataset.html',
#  'json_to_csv_converter.py',
#  'data_hadling.ipynb',
#  'yelp_academic_dataset_checkin.json',
#  'Dataset_User_Agreement.pdf',
#  'yelp_academic_dataset_tip.json',
#  'yelp_academic_dataset_review.json',
#  'yelp_academic_dataset_business.json',
#  'yelp_academic_dataset_user.json']

# %%
data_dict ={}

# %%
for file in files:
    if file.endswith('.json'):        
        # Construct the full file path
        file_path = os.path.join(directory_path, file)
        
        # Read the JSON file
        with open(file_path, 'r', encoding='utf-8') as f:
            data = [json.loads(line) for line in f]
        
        # Convert the list of dictionaries to a DataFrame
        data_dict[file] = pd.DataFrame(data)

# %%
data_dict
# Out:
# {'yelp_academic_dataset_checkin.json':                    business_id  \
#  0       ---kPU91CF4Lq2-WlRu9Lw
#  1       --0iUa4sNDFiZFrAdIWhZQ
#  2       --30_8IhuyMHbSOcNWd6DQ
#  3       --7PUidqRWpRSpXebiyxTg
#  4       --7jw19RH9JKXgFohspgQw
#  ...                        ...
#  131925  zznJox6-nmXlGYNWgTDwQQ
#  131926  zznZqH9CiAznbkV6fXyHWA
#  131927  zzu6_r3DxBJuXcjnOYVdTw
#  131928  zzw66H6hVjXQEt0Js3Mo4A
#  131929  zzyx5x0Z7xXWWvWnZFuxlQ
#
#                                                       date
#  0       2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
#  1       2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
#  2                2013-06-14 23:29:17, 2014-08-13 23:20:22
#  3       2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
#  4       2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
#  ...                                                   ...
#  131925  2013-03-23 16:22:47, 2013-04-07 02:03:12, 2013...
#  131926                                2021-06-12 01:16:12
# ...

# %%
files = 'yelp_academic_dataset_business.json'

# %%
business = data_dict["yelp_academic_dataset_business.json"]
checkin = data_dict["yelp_academic_dataset_checkin.json"]
review = data_dict["yelp_academic_dataset_review.json"]
tip = data_dict["yelp_academic_dataset_tip.json"]
user = data_dict["yelp_academic_dataset_user.json"]

# %%
sub_business = business[business['city']=='Brandon']

# %%
tip[tip['business_id']=='SRexiuEsx1d9-dZVUsssQA']
# Out:
# Empty DataFrame
# Columns: [user_id, business_id, text, date, compliment_count]
# Index: []

# %%
sub_business
# Out:
#                    business_id                      name  \
# 250     my0bmPD5dgDFE1ia__LNlw     Nails & Beauty Lounge
# 339     SRexiuEsx1d9-dZVUsssQA           Brandon Burgers
# 344     mHDBZmEH0Er3184YS83_LQ    Splash Car Wash & Lube
# 357     8YJtf5v76SIz-4udyF4YmA  The Hideout Coffee House
# 383     iBRXLFWD7PeSYDbKsd_JTw       Mai Thai Restaurant
# ...                        ...                       ...
# 149801  q0Q-ohZp8iV9OY-gkNPPwg         Allegria Italiana
# 149953  LfQtJyxvtK08d2uiA0-R0Q       Osaka Ramen & Sushi
# 150044  det-3WomRwAxUFLds20pXA        Essentials Massage
# 150133  TaWCKl6hVCwm2ksdRBIJSQ                     Cicis
# 150278  jYd7okFv6JMjIXMDjZNCDQ                  Ace Golf
#
#                        address     city state postal_code   latitude  \
# 250         953 E Brandon Blvd  Brandon    FL       33511  27.937166
# 339        1513 W Brandon Blvd  Brandon    FL       33511  27.937370
# 344     802 W Bloomingdale Ave  Brandon    FL       33511  27.893920
# ...

# %%
dat
# Out:
# city
# Philadelphia        14569
# Tucson               9250
# Tampa                9050
# Indianapolis         7540
# Nashville            6971
# New Orleans          6209
# Reno                 5935
# Edmonton             5054
# Saint Louis          4827
# Santa Barbara        3829
# Boise                2937
# Clearwater           2221
# Saint Petersburg     1663
# Metairie             1643
# Sparks               1624
# Wilmington           1446
# Franklin             1414
# St. Louis            1255
# St. Petersburg       1185
# Meridian             1043
# Brandon              1033
# Largo                1002
# Name: count, dtype: int64

# %%
checkin.head()
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...

# %%
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0    3.0       0      0     0
# 1    5.0       1      0     1
# 2    3.0       0      0     0
# 3    5.0       1      0     1
# 4    4.0       1      0     1
#
#                                                 text                 date
# 0  If you decide to eat here, just be aware it is...  2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year...  2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm...  2014-02-05 20:30:30
# ...

# %%
review[review['business_id']=='8YJtf5v76SIz-4udyF4YmA']
# Out:
#                      review_id                 user_id  \
# 10339   CxgCjl0_cBOREMU3WQ1XMQ  NG3h5OGAUxDP2nGeGInnnA
# 18619   KIE7Kpt2Spck3sSogF2cVw  xG8Jf5nZSUYjf-kTbVgE8w
# 83379   4Xc3a_qpPvNJew-LKYKneA  KVbyDrL_fIuG0YS_uQlqvw
# 90044   I41pVCoAYAnm3bzLnrOMJw  NTnVSjQG7U-84MEIGu7bfg
# 133950  vsaaJPl_jPJT9Bcx2xFMGg  e5WEN4JC0_p8mgLWwkmkIw
# 161019  lRlgA-ers8ZNwYk2S2mDpg  -EkS5xpjIIRZN8Uy4ui4pg
# 227689  Wh3m2OCAJGBOTHlE7HWL5g  6j4NN66UESCtdcNJulB4fw
# 231975  JWK_27RyaYn-SZ8Er55dDQ  64Wk7lHoENK8pe1zEtOOqQ
# 251455  SrZ1nBCXRDhFJnpp1bozdA  8_VvQeWWiI2VgzNfpQ8RAA
# 282538  kbgpR8tn-Pk7Zro3A_6Pkg  nAPU1-75Gqg71NGr_HosFA
# 288265  pH5icqkQghB4-FS81F6RLg  w2hgu8IC0jvkAuGM9JdCrQ
# 289748  9XXFwv1QLNBEzhHUmrTBPg  sBn5m-GManXNZjsiM7lHnA
# 305900  T347lNZK9tAJFISrqrefRA  FOanfm1MYCAuImX5NuAcBQ
# 319837  rOT4LFMK1WAz-WsYUkm1cg  LfgKRPF06BnxGq3VogkcAg
# 351571  JVrfR1KYXrvrvtezlAaumQ  gtaJKNA6CUKul1CnUnzAUg
# 463898  GnzP7ljATVxZEwOupw8x1A  fbqb-z8c6e7d6SiyM2tHPg
# ...

# %%
tip[tip['business_id']=='8YJtf5v76SIz-4udyF4YmA']
# Out:
#                        user_id             business_id  \
# 31      fjpoZaeM1QRueYLl9FSLiQ  8YJtf5v76SIz-4udyF4YmA
# 104716  bdfZObj8MZ63_C4VoojH8w  8YJtf5v76SIz-4udyF4YmA
# 157922  LfgKRPF06BnxGq3VogkcAg  8YJtf5v76SIz-4udyF4YmA
# 424978  nAPU1-75Gqg71NGr_HosFA  8YJtf5v76SIz-4udyF4YmA
# 493568  gtaJKNA6CUKul1CnUnzAUg  8YJtf5v76SIz-4udyF4YmA
# 503698  s3S5rB93dGoGGHKCi8IzAQ  8YJtf5v76SIz-4udyF4YmA
# 507046  gtaJKNA6CUKul1CnUnzAUg  8YJtf5v76SIz-4udyF4YmA
# 756675  dhODLTrTB6mG9f7tC0dDqw  8YJtf5v76SIz-4udyF4YmA
# 861862  9bbP2v45eQ0pHjTJXBC_ag  8YJtf5v76SIz-4udyF4YmA
#
#                                                      text  \
# 31      This place had great coffee but the owner sold...
# 104716                                        Great place
# 157922  Stopped in for an almond milk latte and chocol...
# 424978  7.15.17 -Went by today & though Yelp says they...
# 493568       Best coffee in brandon and delicious Muffins
# 503698     This place is closed and had been for a while.
# ...

# %%
user.head()
# Out:
#                   user_id    name  review_count        yelping_since  useful  \
# 0  qVc8ODYU5SZjKXVBgXdI7w  Walker           585  2007-01-25 16:47:26    7217
# 1  j14WgRoU_-2ZE1aw1dXrJg  Daniel          4333  2009-01-25 04:35:42   43091
# 2  2WnXYQFK0hXEoTxPtV2zvg   Steph           665  2008-07-25 10:41:00    2086
# 3  SZDeASXq7o05mMNLshsdIA    Gwen           224  2005-11-29 04:38:33     512
# 4  hA5lMy-EnncsH4JoR-hFGQ   Karen            79  2007-01-05 19:40:59      29
#
#    funny   cool                                              elite  \
# 0   1259   5994                                               2007
# 1  13066  27281  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...
# 2   1010   1003                           2009,2010,2011,2012,2013
# 3    330    299                                     2009,2010,2011
# 4     15      7
#
#                                              friends  fans  ...  \
# 0  NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267  ...
# ...
